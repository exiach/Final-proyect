# %%
import pandas as pd

dataset = pd.read_csv("../data/dataset/primaria_dataset.csv")
dataset.columns
dataset.head()
# Out:
#    gestion anio_escolaridad paralelo  nro.  paterno    materno  \
# 0     2022          PRIMERO        B     1      NaN  FERNANDEZ
# 1     2022          PRIMERO        B     2      NaN   HINOJOSA
# 2     2022          PRIMERO        B     3   ALANES    FUENTES
# 3     2022          PRIMERO        B     4  ALVAREZ      SEJAS
# 4     2022          PRIMERO        B     5    APAZA   CARVAJAL
#
#           nombres             rude gen   fecha_nac  ... edu_musical  \
# 0    AYELEN BELEN  809800682020086   F  09-07-2015  ...        84.0
# 1     ARELI LUCIA  609000282018010   F  31-10-2013  ...         NaN
# 2    DESIRE CIELO  809804752020027   F  11-08-2015  ...        79.0
# 3         REYCHEL  809801842020002   F  10-09-2015  ...        73.0
# 4  KAROLAY FELISA  809801202020120   F  28-04-2016  ...        56.0
#
#    art_plasticas matematica  tec_tecnologica  cs_naturales  valores_religion  \
# 0           87.0       89.0             90.0          90.0              91.0
# ...
