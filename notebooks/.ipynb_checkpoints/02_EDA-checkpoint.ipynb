# %%
# !pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 3.4 MB/s  0:00:02 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 3.9 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [matplotlib]6 [matplotlib]
# ...

# %%
import pandas as pd

dataset = pd.read_csv("../data/dataset/primaria_dataset.csv")
dataset.head()
# Out:
#    nro.  paterno    materno         nombres             rude gen   fecha_nac  \
# 0     1      NaN  FERNANDEZ    AYELEN BELEN  809800682020086   F  09-07-2015
# 1     2      NaN   HINOJOSA     ARELI LUCIA  609000282018010   F  31-10-2013
# 2     3   ALANES    FUENTES    DESIRE CIELO  809804752020027   F  11-08-2015
# 3     4  ALVAREZ      SEJAS         REYCHEL  809801842020002   F  10-09-2015
# 4     5    APAZA   CARVAJAL  KAROLAY FELISA  809801202020120   F  28-04-2016
#
#   lug\nnac  numero\nc.i.   estado\nmatricula  ...  cs_sociales  edu_fisica  \
# 0      NaN    15316899.0           PROMOVIDO  ...         90.0        84.0
# 1      CBB    14695195.0  RETIRADO\nABANDONO  ...          NaN         NaN
# 2      CBB    14696127.0           PROMOVIDO  ...         67.0        86.0
# 3      CBB           NaN           PROMOVIDO  ...         55.0        71.0
# 4      CBB    17775068.0           REPROBADO  ...         51.0        61.0
#
# ...

# %%
dataset.shape
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1118 entries, 0 to 1117
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   nro.                     1118 non-null   int64
#  1   paterno                  1091 non-null   object
#  2   materno                  1116 non-null   object
#  3   nombres                  1118 non-null   object
#  4   rude                     1118 non-null   object
#  5   gen                      1118 non-null   object
#  6   fecha_nac                1118 non-null   object
#  7   lug
# nac                  1067 non-null   object
#  8   numero
# c.i.              1092 non-null   float64
#  9   estado
# matricula         1118 non-null   object
#  10  com_lenguajes            1030 non-null   float64
#  11  cs_sociales              1030 non-null   float64
#  12  edu_fisica               1030 non-null   float64
# ...

# %%
dataset["rezago"].value_counts()
dataset["rezago"].value_counts(normalize=True) * 100
# Out:
# rezago
# 0    97.942755
# 1     2.057245
# Name: proportion, dtype: float64

# %%
materias = [
    "com_lenguajes",
    "cs_sociales",
    "edu_fisica",
    "edu_musical",
    "art_plasticas",
    "matematica",
    "tec_tecnologica",
    "cs_naturales",
    "valores_religion"
]

(dataset[materias] < 51).mean().sort_values(ascending=False) * 100
# Out:
# com_lenguajes       2.057245
# matematica          1.699463
# cs_naturales        1.162791
# cs_sociales         0.983900
# valores_religion    0.983900
# tec_tecnologica     0.536673
# edu_musical         0.447227
# art_plasticas       0.447227
# edu_fisica          0.178891
# dtype: float64

# %%
dataset.groupby("rezago")[materias].mean()
# Out:
#         com_lenguajes  cs_sociales  edu_fisica  edu_musical  art_plasticas  \
# rezago
# 0           74.486594    74.479643   78.019861    77.409136      75.926514
# 1           45.956522    49.173913   58.739130    57.608696      53.434783
#
#         matematica  tec_tecnologica  cs_naturales  valores_religion
# rezago
# 0        73.472691        76.271102     75.040715         70.329692
# 1        47.043478        53.130435     49.869565         49.826087

# %%
dataset
# Out:
#       nro.   paterno     materno             nombres              rude gen  \
# 0        1       NaN   FERNANDEZ        AYELEN BELEN   809800682020086   F
# 1        2       NaN    HINOJOSA         ARELI LUCIA   609000282018010   F
# 2        3    ALANES     FUENTES        DESIRE CIELO   809804752020027   F
# 3        4   ALVAREZ       SEJAS             REYCHEL   809801842020002   F
# 4        5     APAZA    CARVAJAL      KAROLAY FELISA   809801202020120   F
# ...    ...       ...         ...                 ...               ...  ..
# 1113    28    TORREZ      COLQUE       EUGENE MATIAS  8098008320214763   M
# 1114    29   TORRICO    GONZALES      AGUSTIN MATTEO  8098055120215690   M
# 1115    30    VARGAS  MONTENEGRO       GUSTAVO ANDRE  8098060020213014   M
# 1116    31  VILLEGAS  DELGADILLO  SEBASTIAN\nNICOLAS  8098051020225260   M
# 1117    32  ZEBALLOS        CRUZ       SHARON BETHEL  6090002820212938   F
#
# ...

# %%
dataset["num_materias_reprobadas"].value_counts().sort_index()
# Out:
# num_materias_reprobadas
# 0    1095
# 2       7
# 3       4
# 4       3
# 5       3
# 6       2
# 7       2
# 8       2
# Name: count, dtype: int64

# %%
dataset.groupby("rezago")["num_materias_reprobadas"].mean()
# Out:
# rezago
# 0    0.000000
# 1    4.130435
# Name: num_materias_reprobadas, dtype: float64

# %%
import matplotlib.pyplot as plt

dataset.boxplot(
    column="num_materias_reprobadas",
    by="rezago",
    grid=False
)
plt.title("Materias reprobadas según rezago")
plt.suptitle("")
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
