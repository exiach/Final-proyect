# %%
# !pip install pdfplumber pandas
# Out:
# Collecting pdfplumber
#   Downloading pdfplumber-0.11.8-py3-none-any.whl.metadata (43 kB)
# Collecting pandas
#   Downloading pandas-2.3.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (91 kB)
# Collecting pdfminer.six==20251107 (from pdfplumber)
#   Downloading pdfminer_six-20251107-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: Pillow>=9.1 in /Users/danielcanqui/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from pdfplumber) (11.2.1)
# Collecting pypdfium2>=4.18.0 (from pdfplumber)
#   Downloading pypdfium2-5.1.0-py3-none-macosx_11_0_arm64.whl.metadata (67 kB)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /Users/danielcanqui/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from pdfminer.six==20251107->pdfplumber) (3.4.2)
# Collecting cryptography>=36.0.0 (from pdfminer.six==20251107->pdfplumber)
#   Downloading cryptography-46.0.3-cp311-abi3-macosx_10_9_universal2.whl.metadata (5.7 kB)
# Requirement already satisfied: numpy>=1.26.0 in /Users/danielcanqui/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/danielcanqui/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting cffi>=2.0.0 (from cryptography>=36.0.0->pdfminer.six==20251107->pdfplumber)
#   Downloading cffi-2.0.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.6 kB)
# Requirement already satisfied: pycparser in /Users/danielcanqui/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=36.0.0->pdfminer.six==20251107->pdfplumber) (2.22)
# Requirement already satisfied: six>=1.5 in /Users/danielcanqui/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pdfplumber-0.11.8-py3-none-any.whl (60 kB)
# Downloading pdfminer_six-20251107-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 3.8 MB/s  0:00:01 eta 0:00:01
# Downloading pandas-2.3.3-cp312-cp312-macosx_11_0_arm64.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 3.9 MB/s  0:00:02 eta 0:00:01
# Downloading cryptography-46.0.3-cp311-abi3-macosx_10_9_universal2.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 4.1 MB/s  0:00:01 eta 0:00:01
# Downloading cffi-2.0.0-cp312-cp312-macosx_11_0_arm64.whl (181 kB)
# Downloading pypdfium2-5.1.0-py3-none-macosx_11_0_arm64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 4.0 MB/s  0:00:00 eta 0:00:01
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, pypdfium2, cffi, pandas, cryptography, pdfminer.six, pdfplumber
#   Attempting uninstall: cffi
#     Found existing installation: cffi 1.17.1
#     Uninstalling cffi-1.17.1:
#       Successfully uninstalled cffi-1.17.1━━━━━━━━━━━━━━━━━━━━━━━━ 3/8 [cffi]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [pdfplumber]8 [pdfminer.six]
# Successfully installed cffi-2.0.0 cryptography-46.0.3 pandas-2.3.3 pdfminer.six-20251107 pdfplumber-0.11.8 pypdfium2-5.1.0 pytz-2025.2 tzdata-2025.2

# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5

# %%
def limpiar_boletin(path):
    import pandas as pd

    raw = pd.read_excel(path, header=None, engine="openpyxl")

    start_row = None
    for i in range(len(raw)):
        row = raw.iloc[i].astype(str).str.lower()
        if row.str.contains("rude").any():
            start_row = i
            break

    if start_row is None:
        raise ValueError(f"No se detectó cabecera en {path}")

    df = pd.read_excel(path, skiprows=start_row, engine="openpyxl")

    df = df.dropna(axis=1, how="all")
    df = df.dropna(axis=0, how="all")

    df.columns = df.columns.astype(str).str.strip().str.lower()

    rude_col = None
    for col in df.columns:
        if "rude" in col.replace(".", ""):
            rude_col = col
            break

    if not rude_col:
        raise ValueError(f"No se encontró RUDE en {path}")

    df = df.rename(columns={rude_col: "rude"})

    materias_map = {
        "pa": "com_lenguajes",
        "pa.1": "cs_sociales",
        "pa.2": "edu_fisica",
        "pa.3": "edu_musical",
        "pa.4": "art_plasticas",
        "pa.5": "matematica",
        "pa.6": "tec_tecnologica",
        "pa.7": "cs_naturales",
        "pa.8": "valores_religion"
    }

    df = df.rename(columns=materias_map)

    df.columns = (
        df.columns
        .str.replace(" ", "_")
        .str.replace("á","a").str.replace("é","e")
        .str.replace("í","i")
        .str.replace("ó","o")
        .str.replace("ú","u")
    )

    for col in materias_map.values():
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors="coerce")

    df = df[df["rude"].notna()]

    return df

# %%
import glob, os, pandas as pd, re

files = glob.glob("boletines_extradios_excel/**/*.xlsx", recursive=True)
files = [f for f in files if not os.path.basename(f).startswith("~$")]

dfs = []

for f in files:
    try:
        df = limpiar_boletin(f)
        dfs.append(df)
    except Exception as e:
        print("⚠️ Error en:", f)
        print("   ", e)

dataset = pd.concat(dfs, ignore_index=True)
print("Total registros:", len(dataset))
# Out:
# Total registros: 1118

# %%
# // Alumnos rezagados
materias = [
    "com_lenguajes",
    "cs_sociales",
    "edu_fisica",
    "edu_musical",
    "art_plasticas",
    "matematica",
    "tec_tecnologica",
    "cs_naturales",
    "valores_religion"
]

dataset["rezago"] = (dataset[materias] < 51).any(axis=1).astype(int)

dataset["rezago"].value_counts()
# Out:
# rezago
# 0    1095
# 1      23
# Name: count, dtype: int64

# %%
dataset.groupby("rezago")[materias].mean()
# Out:
#         com_lenguajes  cs_sociales  edu_fisica  edu_musical  art_plasticas  \
# rezago
# 0           74.486594    74.479643   78.019861    77.409136      75.926514
# 1           45.956522    49.173913   58.739130    57.608696      53.434783
#
#         matematica  tec_tecnologica  cs_naturales  valores_religion
# rezago
# 0        73.472691        76.271102     75.040715         70.329692
# 1        47.043478        53.130435     49.869565         49.826087

# %%
# aniadir nueva columna
dataset["num_materias_reprobadas"] = (dataset[materias] < 51).sum(axis=1)

# %%
dataset
# Out:
#       nro.   paterno     materno             nombres              rude gen  \
# 0        1       NaN   FERNANDEZ        AYELEN BELEN   809800682020086   F
# 1        2       NaN    HINOJOSA         ARELI LUCIA   609000282018010   F
# 2        3    ALANES     FUENTES        DESIRE CIELO   809804752020027   F
# 3        4   ALVAREZ       SEJAS             REYCHEL   809801842020002   F
# 4        5     APAZA    CARVAJAL      KAROLAY FELISA   809801202020120   F
# ...    ...       ...         ...                 ...               ...  ..
# 1113    28    TORREZ      COLQUE       EUGENE MATIAS  8098008320214763   M
# 1114    29   TORRICO    GONZALES      AGUSTIN MATTEO  8098055120215690   M
# 1115    30    VARGAS  MONTENEGRO       GUSTAVO ANDRE  8098060020213014   M
# 1116    31  VILLEGAS  DELGADILLO  SEBASTIAN\nNICOLAS  8098051020225260   M
# 1117    32  ZEBALLOS        CRUZ       SHARON BETHEL  6090002820212938   F
#
#        fecha_nac lug\nnac  numero\nc.i.   estado\nmatricula  ...  cs_sociales  \
# 0     09-07-2015      NaN    15316899.0           PROMOVIDO  ...         90.0
# 1     31-10-2013      CBB    14695195.0  RETIRADO\nABANDONO  ...          NaN
# 2     11-08-2015      CBB    14696127.0           PROMOVIDO  ...         67.0
# 3     10-09-2015      CBB           NaN           PROMOVIDO  ...         55.0
# 4     28-04-2016      CBB    17775068.0           REPROBADO  ...         51.0
# ...          ...      ...           ...                 ...  ...          ...
# 1113  17-03-2017      CBB    16346406.0           PROMOVIDO  ...         57.0
# 1114  10-04-2017      CBB    16781946.0           PROMOVIDO  ...         72.0
# 1115  29-12-2016      CBB    14833922.0           PROMOVIDO  ...         76.0
# 1116  30-12-2016      CBB    15650669.0           PROMOVIDO  ...         83.0
# 1117  13-07-2016       SC    15616522.0           PROMOVIDO  ...         64.0
#
#       edu_fisica  edu_musical  art_plasticas  matematica  tec_tecnologica  \
# 0           84.0         84.0           87.0        89.0             90.0
# 1            NaN          NaN            NaN         NaN              NaN
# 2           86.0         79.0           69.0        67.0             69.0
# 3           71.0         73.0           54.0        55.0             54.0
# 4           61.0         56.0           52.0        51.0             51.0
# ...          ...          ...            ...         ...              ...
# 1113        72.0         63.0           66.0        60.0             61.0
# 1114        82.0         87.0           74.0        71.0             73.0
# 1115        78.0         87.0           79.0        76.0             71.0
# 1116        82.0         68.0           83.0        86.0             86.0
# 1117        81.0         85.0           74.0        72.0             70.0
#
#       cs_naturales  valores_religion  rezago  num_materias_reprobadas
# 0             90.0              91.0       0                        0
# 1              NaN               NaN       0                        0
# 2             66.0              92.0       0                        0
# 3             52.0              65.0       0                        0
# 4             51.0              41.0       1                        2
# ...            ...               ...     ...                      ...
# 1113          63.0              56.0       0                        0
# 1114          78.0              84.0       0                        0
# 1115          71.0              76.0       0                        0
# 1116          87.0              83.0       0                        0
# 1117          73.0              83.0       0                        0
#
# [1118 rows x 21 columns]
