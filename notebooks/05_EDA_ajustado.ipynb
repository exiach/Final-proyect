# %%
# Evolución de rezago por año

dataset.groupby("anio")["rezago"].mean().plot(
    kind="bar",
    title="Proporción de rezago por gestión"
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Evolución de rezago por año
# ----> 3 dataset.groupby("anio")["rezago"].mean().plot(
#       4     kind="bar",
#       5     title="Proporción de rezago por gestión"
#       6 )
#
# NameError: name 'dataset' is not defined
